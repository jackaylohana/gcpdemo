# %%
# %pip list
# Out:
# Package                               Version
# ------------------------------------- -------------------
# absl-py                               1.0.0
# aiohttp                               3.8.1
# aiosignal                             1.2.0
# ansiwrap                              0.8.4
# anyio                                 3.5.0
# appdirs                               1.4.4
# argon2-cffi                           21.3.0
# argon2-cffi-bindings                  21.2.0
# arrow                                 1.2.2
# asn1crypto                            1.5.1
# astunparse                            1.6.3
# async-timeout                         4.0.2
# asynctest                             0.13.0
# attrs                                 21.4.0
# Babel                                 2.9.1
# backcall                              0.2.0
# backports.functools-lru-cache         1.6.4
# beatrix-jupyterlab                    3.1.7
# beautifulsoup4                        4.10.0
# ...

# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
df = pd.read_csv('owid-covid-data.csv')

# %%
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# ...

# %%
df.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed  total_deaths  \
# count  7.277700e+04  7.270200e+04        7.220400e+04  6.612800e+04
# mean   2.527084e+06  1.254814e+04        1.251053e+04  4.752699e+04
# std    1.424411e+07  8.720403e+04        8.519276e+04  2.081364e+05
# min    1.000000e+00  0.000000e+00        0.000000e+00  1.000000e+00
# 25%    2.596000e+03  0.000000e+00        6.429000e+00  7.500000e+01
# 50%    2.151300e+04  5.300000e+01        7.728600e+01  5.400000e+02
# 75%    2.466870e+05  8.240000e+02        8.787498e+02  6.854250e+03
# max    2.806509e+08  2.830540e+06        2.322156e+06  2.333504e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  66121.000000         65628.000000             72777.000000
# mean     132.775654           133.420689             35713.099987
# std      597.923988           580.535737             66576.989433
# min        0.000000             0.000000                 0.001000
# ...
